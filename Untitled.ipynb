# %%
from importlib import reload
from IPython.display import HTML, clear_output
from os import walk
from PIL import Image
import random
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout, Reshape
from tensorflow.keras.datasets import mnist

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

from util import load_data, random_samples, interpolation, animation

# Test
img = Image.open("scrapper/faviconpngs2/google.com.png")

# Convert image to array
np_img = np.array(img)
print(np_img.shape)
# and back
Image.fromarray(np_img, 'RGBA')
# Out:
# (32, 32, 4)
# <PIL.Image.Image image mode=RGBA size=32x32 at 0x7F51307892E8>

# %%
mode = 3

# %%
imgs = load_data('scrapper/faviconpngs2/', mode)
# Out:
# /usr/local/lib/python3.5/dist-packages/PIL/Image.py:931: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')

# %%
imgs[3].shape
# Out:
# (32, 32, 3)

# %%
# Filter out images with strange dimensions
desired_shape = (32, 32, mode)

print('num images before: ' + str(len(imgs)))
imgs = [img for img in imgs if img.shape == desired_shape]
print('num images after: ' + str(len(imgs)))
# Out:
# num images before: 61725
# num images after: 60561

# %%
random_samples(imgs, mode)

# %%
X_train = np.asarray(imgs)

# %%
import conv_gan as gan_module
reload(gan_module)
GAN = gan_module.GAN
# Out:
# Using TensorFlow backend.

# %%
save_path = "icons/"
gan = GAN(desired_shape, save_path=save_path)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        448
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 16)        64
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 32, 32, 16)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        4640
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          18496
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 8, 8, 64)          256
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               1048704
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_3 (Dense)              (None, 16)                1040
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 1,155,777
# Trainable params: 1,155,617
# Non-trainable params: 160
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 131072)            13238272
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 32, 32, 128)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32, 32, 128)       512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 128)       147584
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 128)       0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 32, 32, 128)       512
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 32, 64)        73792
# _________________________________________________________________
# activation_2 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 64, 64, 32)        18464
# _________________________________________________________________
# activation_3 (Activation)    (None, 64, 64, 32)        0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 64, 64, 32)        128
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 128, 128, 16)      4624
# _________________________________________________________________
# activation_4 (Activation)    (None, 128, 128, 16)      0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 128, 128, 16)      64
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 64, 64, 16)        4112
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 32, 32, 16)        4112
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 32, 32, 3)         435
# _________________________________________________________________
# activation_5 (Activation)    (None, 32, 32, 3)         0
# =================================================================
# Total params: 13,492,867
# Trainable params: 13,492,131
# Non-trainable params: 736
# _________________________________________________________________

# %%
d_loss, d_acc, g_loss = gan.train(X_train=X_train, epochs=30000, batch_size=32, sample_interval=200)
clear_output()

# %%
Image.open(save_path + "29800.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=432x288 at 0x7F51307899E8>

# %%
plt.plot(d_loss)

# %%
plt.plot(d_acc)

# %%
plt.plot(g_loss)

# %%
r, c = 4, 4
noise = np.random.normal(0, 1, (r * int(c/2), 100))

gen_imgs1 = gan.g1.predict(noise)
gen_imgs2 = gan.g2.predict(noise)
gen_imgs = np.concatenate([gen_imgs1, gen_imgs2])
gen_imgs = 0.5 * gen_imgs + 0.5

random_samples(gen_imgs, mode)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-cc5d7bccdb5c> in <module>()
#       2 noise = np.random.normal(0, 1, (r * int(c/2), 100))
#       3
# ----> 4 gen_imgs1 = gan.g1.predict(noise)
#       5 gen_imgs2 = gan.g2.predict(noise)
#       6 gen_imgs = np.concatenate([gen_imgs1, gen_imgs2])
#
# AttributeError: 'GAN' object has no attribute 'g1'

# %%
plt.imshow(gen_imgs[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-ffb11ba2ba65> in <module>()
# ----> 1 plt.imshow(gen_imgs[1])
#
# NameError: name 'gen_imgs' is not defined

# %%
r,c,steps = 4,6,31
interpol = interpolation(gan,r*c,steps)
HTML(animation(interpol,mode,r,c,steps).to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgd3bfa7c8e0b5445784e23277106032bb">
#     <br>
#     <input id="_anim_sliderd3bfa7c8e0b5445784e23277106032bb" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animd3bfa7c8e0b5445784e23277106032bb.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animd3bfa7c8e0b5445784e23277106032bb.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="animd3bfa7c8e0b5445784e23277106032bb.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="animd3bfa7c8e0b5445784e23277106032bb.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="animd3bfa7c8e0b5445784e23277106032bb.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="animd3bfa7c8e0b5445784e23277106032bb.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="animd3bfa7c8e0b5445784e23277106032bb.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="animd3bfa7c8e0b5445784e23277106032bb.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="animd3bfa7c8e0b5445784e23277106032bb.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="animd3bfa7c8e0b5445784e23277106032bb.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selectd3bfa7c8e0b5445784e23277106032bb" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgd3bfa7c8e0b5445784e23277106032bb";
#     var slider_id = "_anim_sliderd3bfa7c8e0b5445784e23277106032bb";
#     var loop_select_id = "_anim_loop_selectd3bfa7c8e0b5445784e23277106032bb";
#     var frames = new Array(31);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4wLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvqOYd8AAAIABJREFUeJzsvWmwZVl21/fb+0x3fPN7OQ+VmZVZ\
# 1VXV3aUe1EJolmjCLYEwwgiMIwALDIQIZMtGgLGw5AgbbDmCCBuH+GAMoRDGlhklFEhgSZbUUg+q\
# 6qGquubKrJzz5cs33ulMe/vDWufcmzV05usaul9y/h+q7rt57jl7n7PPXnv991r/Zbz3ngYNGjRo\
# 0OCAwX69G9CgQYMGDRp8LWgMWIMGDRo0OJBoDFiDBg0aNDiQaAxYgwYNGjQ4kGgMWIMGDRo0OJBo\
# DFiDBg0aNDiQaAxYgwYNGjQ4kGgMWIMGDRo0OJBoDFiDBg0aNDiQaAxYgwYNGjQ4kGgMWIMGDRo0\
# OJBoDFiDBg0aNDiQaAxYgwYNGjQ4kGgMWIMGDRo0OJBoDFiDBg0aNDiQaAxYgwYNGjQ4kGgMWIMG\
# DRo0OJBoDFiDBg0aNDiQaAxYgwYNGjQ4kGgMWIMGDRo0OJBoDFiDBg0aNDiQaAxYgwYNGjQ4kGgM\
# WIMGDRo0OJBoDFiDBg0aNDiQaAxYgwYNGjQ4kGgMWIMGDRo0OJBoDFiDBg0aNDiQaAxYgwYNGjQ4\
# kGgMWIMGDRo0OJBoDFiDBg0aNDiQaAxYgwYNGjQ4kGgMWIMGDRo0OJBoDFiDBg0aNDiQaAxYgwYN\
# GjQ4kAi/3g14rzC3cJzxeBMA50qMke+NMRj9w1qLMYEc4x3eOz3GYm1YH2Ot2Pk4igkDvWXeU+Q5\
# AFmekxeZfu0wenwUJXTbHQCW5xc5t7YMwJPnzvPYhz4OwLGHL3Dk1BEAFtcWaHdbACTdzn310xUl\
# JtjHOsQD5q3/qernm65Ryn150+/czOe3Oefb/rvz8vV9tL1cf5U8lfuRDhx3PvcSAJdeeIUXrt0C\
# 4JWb10n1GSz22pw+egiAh4+tkLTlGe9sDLj80kUAXrx+iWEhz28Q9didXwOg//DjfPDjHwTgo0+c\
# 4NTaHACHF9okcVh3xdQDCgzTz3WbxxMifYbe+3v2cWnlDJPRpp7GE8z235X1/8t6jII1cu/CMCK0\
# 8gvvPKUrAChcSenkeI+jakbddmSsV3+6md/iZh/uG6A/CKIEr8eX+i7cC7PXPoi4n2dpjGF+Tp7H\
# xT/33bT7GwC4zQG+lN/7NriOHJOmht2JjK3LuxHPDHsADOIF1sa3AejGnqGVe7eetmn3ZC45tnKK\
# E4+cAGB57RCHH38IgE7/CNHqqfesj98oaDywBg0aNGhwIPHAemAQUdlng4O7VhXVktOAUU/AA16+\
# N9Zg9beBTYgi8Ypa7S5REMtPvcfYiXxmiNPflmVer8iNs3gnxw9Ty4t3ZCV9aXSdX331twA4tHad\
# b/7Y7wfg+z/Z5eEL3f118228prfFV1kAu9lVt6uX63f/5q0WZ19tUf12/7aPhbhvrVIOZaWfXt8h\
# uyWe1mR9F7e5LZ9vX2FjMgLgetzjyh35fOlGxuF58aLCYsLe9hiAfFKSZ/L8Bn7CtnoQ6fwy19aP\
# A7C2scDhRVkNW2ux5s2elsG8ZV9sGN9/BwFjEzCVh+dr70oYA+m7NwVevTGPB/W6TJAQhi29WQ5T\
# SL98meHR377hudUshAnqa3nryPS4kpy3fthg9bqRiSibJfBbYmdXntOktUlepPJllOFiue/OQDaW\
# Z7OTBVwfyiGvDUOe25P7u5cVjEvxtMqiBB2jpStpdeQ8Z/KY63EbgMfiQ/QH4o11olkf/sHFA2vA\
# vC+nfxhz9xusNIzDY/xbzD5eqBWAKGqRdBcA6Mwtk7Tn5ZTWkI13ARjtbjIe7gCQpyPKMtdjgtoO\
# 5M5htE1lPiIf5Pp9ytLFwwBsbp7Eu/l9dpS3NTB+xga9Ld7u3+xb35d7/fZNh1Rf
